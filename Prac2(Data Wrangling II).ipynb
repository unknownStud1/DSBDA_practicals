# %%
csv_url = "file:///Users/Avdhut/Downloads/Data%20Science/practial2.csv"

import pandas as pd

stud = pd.read_csv(csv_url)

stud
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Year  \
# 0          NaN             85             59               80            2022
# 1         80.0             75             82               74            2021
# 2         77.0             72             78               71            2022
# 3         94.0             74             90               83            2022
# 4         81.0             76             83               85            2022
# 5         76.0             71             77               69            2021
# 6         92.0             70             76               78            2022
# 7         77.0             73             99               81            2022
# 8         98.0             88             78               90            2019
# 9          NaN             89             79               91            2018
# 10       120.0             75             78               70            2021
# ...

# %%
# for finding missing values

# 1. isnull()
stud.isnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Year  \
# 0         True          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5        False          False          False            False           False
# 6        False          False          False            False           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9         True          False          False            False           False
# 10       False          False          False            False           False
# ...

# %%
# 2. isna()
stud.isna()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Year  \
# 0         True          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5        False          False          False            False           False
# 6        False          False          False            False           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9         True          False          False            False           False
# 10       False          False          False            False           False
# ...

# %%
# 3. notnull() - reverse of isnull()
stud.notnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Year  \
# 0        False           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5         True           True           True             True            True
# 6         True           True           True             True            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9        False           True           True             True            True
# 10        True           True           True             True            True
# ...

# %%
no_math_score = pd.isnull(stud["Math_Score"])

# %%
no_math_score
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# Name: Math_Score, dtype: bool

# %%
stud[no_math_score]
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Year  \
# 0          NaN             85             59               80            2022
# 9          NaN             89             79               91            2018
# 17         NaN             76             81               64            2018
# 27         NaN             77             75               82            2018
#
#     Placement_offer_count  Gender
# 0                       2    Male
# 9                       3  Female
# 17                      2  Female
# 27                      2    Male

# %%
#  checking non - missing values using notnull()

no_math_score1 = pd.notnull(stud["Math_Score"])

stud[no_math_score1]
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Year  \
# 1         80.0             75             82               74            2021
# 2         77.0             72             78               71            2022
# 3         94.0             74             90               83            2022
# 4         81.0             76             83               85            2022
# 5         76.0             71             77               69            2021
# 6         92.0             70             76               78            2022
# 7         77.0             73             99               81            2022
# 8         98.0             88             78               90            2019
# 10       120.0             75             78               70            2021
# 11        90.0             85             42               92            2019
# 12        75.0             78             76               85            2018
# ...

# %%
# handling categorial variables 

# 1. Label encoder

from sklearn import preprocessing 
le = preprocessing.LabelEncoder()

# %%
stud["Gender"] = le.fit_transform(stud["Gender"])

# %%
stud['Gender']
# Out:
# 0     1
# 1     0
# 2     1
# 3     0
# 4     1
# 5     1
# 6     0
# 7     0
# 8     0
# 9     0
# 10    1
# 11    1
# 12    0
# 13    0
# 14    1
# 15    1
# 16    0
# 17    0
# 18    1
# 19    1
# 20    1
# 21    0
# 22    1
# 23    0
# 24    0
# 25    1
# 26    0
# 27    1
# 28    0
# 29    1
# Name: Gender, dtype: int64

# %%
stud
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Year  \
# 0          NaN             85             59               80            2022
# 1         80.0             75             82               74            2021
# 2         77.0             72             78               71            2022
# 3         94.0             74             90               83            2022
# 4         81.0             76             83               85            2022
# 5         76.0             71             77               69            2021
# 6         92.0             70             76               78            2022
# 7         77.0             73             99               81            2022
# 8         98.0             88             78               90            2019
# 9          NaN             89             79               91            2018
# 10       120.0             75             78               70            2021
# ...

# %%
# filling missing data with mean()

stud.describe(include="all")
# Out:
#        Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# count   26.000000      30.000000      30.000000        30.000000
# mean    83.461538      79.833333      75.866667        81.700000
# std     11.510798       5.760049      10.125874         8.867414
# min     75.000000      70.000000      42.000000        55.000000
# 25%     76.250000      75.250000      76.000000        80.000000
# 50%     78.500000      79.000000      77.000000        83.000000
# 75%     87.750000      84.750000      79.000000        87.750000
# max    120.000000      90.000000      99.000000        94.000000
#
#        Club_Join_Year  Placement_offer_count     Gender
# count       30.000000              30.000000  30.000000
# mean      2019.833333               2.433333   0.500000
# std          1.555487               0.504007   0.508548
# min       2018.000000               2.000000   0.000000
# 25%       2018.000000               2.000000   0.000000
# ...

# %%
stud['Math_Score'].isnull().sum()
# Out:
# 4

# %%
stud["Math_Score"] = stud["Math_Score"].fillna(stud["Math_Score"].mean(),inplace=True)

# %%
stud
# Out:
#    Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Year  \
# 0        None             85             59               80            2022
# 1        None             75             82               74            2021
# 2        None             72             78               71            2022
# 3        None             74             90               83            2022
# 4        None             76             83               85            2022
# 5        None             71             77               69            2021
# 6        None             70             76               78            2022
# 7        None             73             99               81            2022
# 8        None             88             78               90            2019
# 9        None             89             79               91            2018
# 10       None             75             78               70            2021
# ...

# %%
newstud = pd.read_csv(csv_url)

newstud
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Year  \
# 0          NaN             85             59               80            2022
# 1         80.0             75             82               74            2021
# 2         77.0             72             78               71            2022
# 3         94.0             74             90               83            2022
# 4         81.0             76             83               85            2022
# 5         76.0             71             77               69            2021
# 6         92.0             70             76               78            2022
# 7         77.0             73             99               81            2022
# 8         98.0             88             78               90            2019
# 9          NaN             89             79               91            2018
# 10       120.0             75             78               70            2021
# ...

# %%
newstud["Math_Score"] = newstud["Math_Score"].fillna(newstud["Math_Score"].mean())

# for mean => mean()
# for median => median()

# %%
newstud
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Year  \
# 0    83.461538             85             59               80            2022
# 1    80.000000             75             82               74            2021
# 2    77.000000             72             78               71            2022
# 3    94.000000             74             90               83            2022
# 4    81.000000             76             83               85            2022
# 5    76.000000             71             77               69            2021
# 6    92.000000             70             76               78            2022
# 7    77.000000             73             99               81            2022
# 8    98.000000             88             78               90            2019
# 9    83.461538             89             79               91            2018
# 10  120.000000             75             78               70            2021
# ...

# %%
newstud1 = pd.read_csv(csv_url)

newstud1
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Year  \
# 0          NaN             85             59               80            2022
# 1         80.0             75             82               74            2021
# 2         77.0             72             78               71            2022
# 3         94.0             74             90               83            2022
# 4         81.0             76             83               85            2022
# 5         76.0             71             77               69            2021
# 6         92.0             70             76               78            2022
# 7         77.0             73             99               81            2022
# 8         98.0             88             78               90            2019
# 9          NaN             89             79               91            2018
# 10       120.0             75             78               70            2021
# ...

# %%
newstud1.replace(to_replace = np.nan, value = -100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 newstud1.replace(to_replace = np.nan, value = -100)
#
# NameError: name 'np' is not defined

# %%
import numpy as np

newstud1.replace(to_replace = np.nan, value = -100)

# %%
newstud2 = pd.read_csv(csv_url)

# %%
newstud2.dropna()

# %%
newstud2.dropna(axis = 1)

# %%
newstud3 = pd.read_csv(csv_url)

newstud3

# %%
newstud3.dropna()

# %%
newstud["Math_Score"].isnull().sum()

# %%
newstud3["Math_Score"].isnull().sum()

# %%
print(newstud3)

# %%
newstud3.dropna(axis=0,how="any")

# %%
newstud3["Math_Score"].isnull().sum()

# %%
print(newstud3)

# %%
# Handling Outliers

# 1. Box Plot

newStud = pd.read_csv(csv_url)
newStud

# %%
newStud.boxplot()

# %%
# by specifying columns 

col = ["Math_Score","Reading_Score","Writing_Score","Placement_Score"]

newStud.boxplot(col)

# %%
newStud.boxplot(['Math_Score','Reading_Score','Writing_Score','Placement_Score'])

# %%
newStud1 = pd.read_csv(csv_url)

# %%
newStud1.boxplot(['Math_Score','Reading_Score','Writing_Score','Placement_Score'])

# %%
import matplotlib.pyplot as plt

# %%
newStud

# %%
newStud.dropna(axis=0,how="any")

# %%
newStud

# %%
import matplotlib.pyplot as plt

newStud.boxplot()

# %%
newStud["Math_Score"] = newStud["Math_Score"].fillna(newStud["Math_Score"].mean())

# %%
newStud

# %%
newStud.boxplot()

# %%
pd.get_dummies?

# %%
pd.isnull?

# %%
preprocessing.LabelEncoder.fit_transform?

# %%
newStud
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 newStud
#
# NameError: name 'newStud' is not defined

# %%
stud
# Out:
#    Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Year  \
# 0        None             85             59               80            2022
# 1        None             75             82               74            2021
# 2        None             72             78               71            2022
# 3        None             74             90               83            2022
# 4        None             76             83               85            2022
# 5        None             71             77               69            2021
# 6        None             70             76               78            2022
# 7        None             73             99               81            2022
# 8        None             88             78               90            2019
# 9        None             89             79               91            2018
# 10       None             75             78               70            2021
# ...

# %%
newStud = pd.read_csv(csv_url)

# %%
newStud
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Year  \
# 0          NaN             85             59               80            2022
# 1         80.0             75             82               74            2021
# 2         77.0             72             78               71            2022
# 3         94.0             74             90               83            2022
# 4         81.0             76             83               85            2022
# 5         76.0             71             77               69            2021
# 6         92.0             70             76               78            2022
# 7         77.0             73             99               81            2022
# 8         98.0             88             78               90            2019
# 9          NaN             89             79               91            2018
# 10       120.0             75             78               70            2021
# ...

# %%
newStud["Math_Score"] = newStud["Math_Score"].fillna(newStud["Math_Score"].mean())

# %%
newStud
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Year  \
# 0    83.461538             85             59               80            2022
# 1    80.000000             75             82               74            2021
# 2    77.000000             72             78               71            2022
# 3    94.000000             74             90               83            2022
# 4    81.000000             76             83               85            2022
# 5    76.000000             71             77               69            2021
# 6    92.000000             70             76               78            2022
# 7    77.000000             73             99               81            2022
# 8    98.000000             88             78               90            2019
# 9    83.461538             89             79               91            2018
# 10  120.000000             75             78               70            2021
# ...

# %%
newStud.boxplot(["Math_Score","Writing_Score","Reading_Score","Placement_Score"])
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize = (18,10))

ax.scatter(newStud["Placement_Score"],newStud["Placement_offer_count"])

plt.show()

# %%
np.where((newStud["Placement_Score"] <= 85) & (newStud["Placement_offer_count"] > 2))
# Out:
# (array([22, 29]),)

# %%
# Detecting outlier using ZScore


from scipy import stats

z = np.abs(stats.zscore(newStud["Math_Score"]))

z
# Out:
# 0     0.000000
# 1     0.329423
# 2     0.614924
# 3     1.002911
# 4     0.234257
# 5     0.710090
# 6     0.812578
# 7     0.614924
# 8     1.383578
# 9     0.000000
# 10    3.477246
# 11    0.622244
# 12    0.805257
# 13    0.424590
# 14    2.335245
# 15    0.710090
# 16    0.614924
# 17    0.000000
# 18    0.805257
# 19    0.519757
# 20    0.424590
# 21    1.288411
# 22    0.710090
# 23    0.805257
# 24    0.519757
# 25    0.424590
# 26    0.329423
# 27    0.000000
# 28    0.614924
# 29    0.710090
# Name: Math_Score, dtype: float64

# %%
out = np.where(z < .18)

# %%
out
# Out:
# (array([ 0,  9, 17, 27]),)

# %%
# detecting outlier using IQR
